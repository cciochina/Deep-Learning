# %% [markdown]
# ## Preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("./drive/MyDrive/DL/resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME  ... ASK_AMT IS_SUCCESSFUL
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB  ...    5000             1
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR  ...  108590             1
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  ...    5000             0
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  ...    6692             1
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT  ...  142590             1
#
# [5 rows x 12 columns]

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
# application_df = application_df.drop(['EIN','NAME'], 1)
# application_df = application_df.drop(['AFFILIATION','USE_CASE'], 1)
# application_df

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
application_df.nunique()
# Out:
# EIN                       34299
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
application_counts = application_df['APPLICATION_TYPE'].value_counts()
application_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T15        2
# T29        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_to_replace = list(application_counts[application_counts < 50].index)
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# Other       54
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
class_counts = application_df['CLASSIFICATION'].value_counts()
class_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C5200        1
# C4200        1
# C2561        1
# C1732        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >50
#  YOUR CODE GOES HERE
class_counts[class_counts > 50]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = list(class_counts[class_counts < 600].index)
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
application_with_dummies_df = pd.get_dummies(application_df)
application_with_dummies_df
# Out:
#              EIN  STATUS  ...  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0       10520599       1  ...                         1                         0
# 1       10531628       1  ...                         1                         0
# 2       10547893       1  ...                         1                         0
# 3       10553066       1  ...                         1                         0
# 4       10556103       1  ...                         1                         0
# ...          ...     ...  ...                       ...                       ...
# 34294  996009318       1  ...                         1                         0
# 34295  996010315       1  ...                         1                         0
# 34296  996012607       1  ...                         1                         0
# 34297  996015768       1  ...                         1                         0
# 34298  996086871       1  ...                         1                         0
#
# [34299 rows x 19616 columns]

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE

X = application_with_dummies_df.drop(['IS_SUCCESSFUL'], axis='columns').values
y = application_with_dummies_df['IS_SUCCESSFUL'].values

# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 100
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu')
)
# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu')
)

# Third hidden layer
#  YOUR CODE GOES HERE
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='relu')
)
# Output layer
#  YOUR CODE GOES HERE
nn.add(
    tf.keras.layers.Dense(units=1, activation='sigmoid')
)
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 100)               3600
#
#  dense_19 (Dense)            (None, 30)                3030
#
#  dense_20 (Dense)            (None, 10)                310
#
#  dense_21 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 6,951
# Trainable params: 6,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 30s 2ms/step - loss: 0.6267 - accuracy: 0.6419
# Epoch 2/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6160 - accuracy: 0.6484
# Epoch 3/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6141 - accuracy: 0.6517
# Epoch 4/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6127 - accuracy: 0.6522
# Epoch 5/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6130 - accuracy: 0.6515
# Epoch 6/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6121 - accuracy: 0.6508
# Epoch 7/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6111 - accuracy: 0.6527
# Epoch 8/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6113 - accuracy: 0.6516
# Epoch 9/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6111 - accuracy: 0.6517
# Epoch 10/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6108 - accuracy: 0.6528
# Epoch 11/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6111 - accuracy: 0.6519
# Epoch 12/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6101 - accuracy: 0.6529
# Epoch 13/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6103 - accuracy: 0.6553
# Epoch 14/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6101 - accuracy: 0.6510
# Epoch 15/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6101 - accuracy: 0.6537
# Epoch 16/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6094 - accuracy: 0.6535
# Epoch 17/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6094 - accuracy: 0.6541
# Epoch 18/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6094 - accuracy: 0.6534
# Epoch 19/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6095 - accuracy: 0.6542
# Epoch 20/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6093 - accuracy: 0.6541
# Epoch 21/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6088 - accuracy: 0.6538
# Epoch 22/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6086 - accuracy: 0.6548
# Epoch 23/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6084 - accuracy: 0.6540
# Epoch 24/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6087 - accuracy: 0.6551
# Epoch 25/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6089 - accuracy: 0.6541
# Epoch 26/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6084 - accuracy: 0.6540
# Epoch 27/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6083 - accuracy: 0.6551
# Epoch 28/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6080 - accuracy: 0.6541
# Epoch 29/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6084 - accuracy: 0.6552
# Epoch 30/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6079 - accuracy: 0.6555
# Epoch 31/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6083 - accuracy: 0.6536
# Epoch 32/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6080 - accuracy: 0.6551
# Epoch 33/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6078 - accuracy: 0.6540
# Epoch 34/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6079 - accuracy: 0.6550
# Epoch 35/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6077 - accuracy: 0.6553
# Epoch 36/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6077 - accuracy: 0.6553
# Epoch 37/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6071 - accuracy: 0.6551
# Epoch 38/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6072 - accuracy: 0.6556
# Epoch 39/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6071 - accuracy: 0.6550
# Epoch 40/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6073 - accuracy: 0.6553
# Epoch 41/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6073 - accuracy: 0.6557
# Epoch 42/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6070 - accuracy: 0.6553
# Epoch 43/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6069 - accuracy: 0.6558
# Epoch 44/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6071 - accuracy: 0.6556
# Epoch 45/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6065 - accuracy: 0.6554
# Epoch 46/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6069 - accuracy: 0.6545
# Epoch 47/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6068 - accuracy: 0.6559
# Epoch 48/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6066 - accuracy: 0.6558
# Epoch 49/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6064 - accuracy: 0.6555
# Epoch 50/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6067 - accuracy: 0.6560

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6158 - accuracy: 0.6505 - 436ms/epoch - 2ms/step
# Loss: 0.6158154606819153, Accuracy: 0.6504956483840942

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save('AlphabetSoupCharity_Optimization.h5')
